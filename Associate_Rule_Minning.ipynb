# %% [markdown]
# <a href="https://colab.research.google.com/github/neel26desai/cmpe255_assignment2/blob/main/Associate_Rule_Minning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install --no-cache-dir --use-deprecated=legacy-resolver pycaret==2.1.2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# ...

# %%
# check installed version
import pycaret
print(pycaret.__version__)
# Out:
# 2.0.0

# %%
from pycaret.arules import *

# %%
from pycaret.datasets import get_data
data = get_data('germany')
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#        InvoiceDate  UnitPrice  CustomerID  Country
# 0  12/1/2010 13:04       2.95       12662  Germany
# 1  12/1/2010 13:04       2.55       12662  Germany
# 2  12/1/2010 13:04       0.85       12662  Germany
# 3  12/1/2010 13:04       1.65       12662  Germany
# 4  12/1/2010 13:04       1.95       12662  Germany

# %%
data.shape
# Out:
# (9495, 8)

# %%
from pycaret.arules import setup
arules_setup = setup(data=data, transaction_id='InvoiceNo', item_id='Description')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdb3d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_bdb3d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bdb3d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bdb3d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bdb3d_row0_col1" class="data row0 col1" >2760</td>
#     </tr>
#     <tr>
#       <td id="T_bdb3d_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_bdb3d_row1_col1" class="data row1 col1" >603</td>
#     </tr>
#     <tr>
#       <td id="T_bdb3d_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_bdb3d_row2_col1" class="data row2 col1" >1703</td>
#     </tr>
#     <tr>
#       <td id="T_bdb3d_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_bdb3d_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = create_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
model.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (24, 10)

# %%
model.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                          antecedents consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND , ROUND SN...   (POSTAGE)
# 1                        (PLASTERS IN TIN STRONGMAN)   (POSTAGE)
# 2                         (PLASTERS IN TIN SPACEBOY)   (POSTAGE)
# 3                           (WOODLAND CHARLOTTE BAG)   (POSTAGE)
# 4               (ROUND SNACK BOXES SET OF 4 FRUITS )   (POSTAGE)
#
#    antecedent support  consequent support  support  confidence    lift  \
# 0              0.1028              0.6352   0.0945      0.9194  1.4474
# 1              0.0564              0.6352   0.0514      0.9118  1.4355
# ...

# %%
#checkout all the rules with their condifenec
model[['antecedents','support']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#                                           antecedents  support
# 0   (ROUND SNACK BOXES SET OF4 WOODLAND , ROUND SN...   0.0945
# 1                         (PLASTERS IN TIN STRONGMAN)   0.0514
# 2                          (PLASTERS IN TIN SPACEBOY)   0.0763
# 3                            (WOODLAND CHARLOTTE BAG)   0.0879
# 4                (ROUND SNACK BOXES SET OF 4 FRUITS )   0.1144
# 5                               (SPACEBOY LUNCH BOX )   0.0697
# 6               (ROUND SNACK BOXES SET OF4 WOODLAND )   0.1708
# 7                                (LUNCH BAG WOODLAND)   0.0514
# 8                            (6 RIBBONS RUSTIC CHARM)   0.0697
# ...
