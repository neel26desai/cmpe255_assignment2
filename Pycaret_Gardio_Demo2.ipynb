# %% [markdown]
# <a href="https://colab.research.google.com/github/neel26desai/cmpe255_assignment2/blob/main/Pycaret_Gardio_Demo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pycaret + Gradio Demo for sentiment analysis on amazon app reviews

# %%
# !pip install pycaret

# %%
# !pip install pycaret[mlops]

# %%
from pycaret.datasets import get_data
data = get_data('amazon')

# %%
data=get_data('amazon')
# Out:
#                                           reviewText  Positive
# 0  This is a one of the best apps acording to a b...         1
# 1  This is a pretty good version of the game for ...         1
# 2  this is a really cool game. there are a bunch ...         1
# 3  This is a silly game and can be frustrating, b...         1
# 4  This is a terrific game on any pad. Hrs of fun...         1

# %%
from pycaret.classification import *

# %%
s= setup(data,target='Positive',session_id=127)
# Out:
# <style type="text/css">
# #T_ea01d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ea01d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea01d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ea01d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea01d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea01d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ea01d_row0_col1" class="data row0 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_ea01d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea01d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ea01d_row1_col1" class="data row1 col1" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_ea01d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt =create_model('dt')
# Out:
# <style type="text/css">
# #T_3e6f3_row10_col0, #T_3e6f3_row10_col1, #T_3e6f3_row10_col2, #T_3e6f3_row10_col3, #T_3e6f3_row10_col4, #T_3e6f3_row10_col5, #T_3e6f3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3e6f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e6f3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3e6f3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3e6f3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3e6f3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3e6f3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3e6f3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3e6f3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
create_app(dt)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
